# %% [markdown]
# Credit: https://medium.com/@ageitgey/machine-learning-is-fun-part-8-how-to-intentionally-trick-neural-networks-b55da32b7196?fbclid=IwAR3SV2kc22jedAtiZzUSvrBp5ZvYZyVzSSLIYTICOQEiHe64oVpzzUgtzug

# %%
# !wget https://i.imgur.com/kKDnjWw.png -O cat.png
# Out:
# --2019-01-13 12:47:23--  https://i.imgur.com/kKDnjWw.png
# Resolving i.imgur.com (i.imgur.com)... 151.101.184.193
# Connecting to i.imgur.com (i.imgur.com)|151.101.184.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153810 (150K) [image/png]
# Saving to: ‘cat.png’
#
# cat.png             100%[===================>] 150.21K  --.-KB/s    in 0.03s
#
# 2019-01-13 12:47:23 (4.85 MB/s) - ‘cat.png’ saved [153810/153810]

# %%
import numpy as np
from keras.preprocessing import image
from keras.applications import inception_v3
from keras import backend as K
from PIL import Image
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# Load pre-trained image recognition model
model = inception_v3.InceptionV3()

# Grab a reference to the first and last layer of the neural net
model_input_layer = model.layers[0].input
model_output_layer = model.layers[-1].output

# Choose an ImageNet object to fake
# The list of classes is available here: https://gist.github.com/ageitgey/4e1342c10a71981d0b491e1b8227328b
# Class #859 is "toaster"
object_type_to_fake = 859

# Load the image to hack
img = image.load_img("cat.png", target_size=(299, 299))
original_image = image.img_to_array(img)

# Scale the image so all pixel intensities are between [-1, 1] as the model expects
original_image /= 255.
original_image -= 0.5
original_image *= 2.

# Add a 4th dimension for batch size (as Keras expects)
original_image = np.expand_dims(original_image, axis=0)

# Pre-calculate the maximum change we will allow to the image
# We'll make sure our hacked image never goes past this so it doesn't look funny.
# A larger number produces an image faster but risks more distortion.
max_change_above = original_image + 0.01
max_change_below = original_image - 0.01

# Create a copy of the input image to hack on
hacked_image = np.copy(original_image)

# How much to update the hacked image in each iteration
learning_rate = 0.1

# Define the cost function.
# Our 'cost' will be the likelihood out image is the target class according to the pre-trained model
cost_function = model_output_layer[0, object_type_to_fake]

# We'll ask Keras to calculate the gradient based on the input image and the currently predicted class
# In this case, referring to "model_input_layer" will give us back image we are hacking.
gradient_function = K.gradients(cost_function, model_input_layer)[0]

# Create a Keras function that we can call to calculate the current cost and gradient
grab_cost_and_gradients_from_model = K.function([model_input_layer, K.learning_phase()], [cost_function, gradient_function])

cost = 0.0

# In a loop, keep adjusting the hacked image slightly so that it tricks the model more and more
# until it gets to at least 80% confidence
while cost < 0.80:
    # Check how close the image is to our target class and grab the gradients we
    # can use to push it one more step in that direction.
    # Note: It's really important to pass in '0' for the Keras learning mode here!
    # Keras layers behave differently in prediction vs. train modes!
    cost, gradients = grab_cost_and_gradients_from_model([hacked_image, 0])

    # Move the hacked image one step further towards fooling the model
    hacked_image += gradients * learning_rate

    # Ensure that the image doesn't ever change too much to either look funny or to become an invalid image
    hacked_image = np.clip(hacked_image, max_change_below, max_change_above)
    hacked_image = np.clip(hacked_image, -1.0, 1.0)

    print("Model's predicted likelihood that the image is a toaster: {:.8}%".format(cost * 100))

# De-scale the image's pixels from [-1, 1] back to the [0, 255] range
img = hacked_image[0]
img /= 2.
img += 0.5
img *= 255.

# Save the hacked image!
im = Image.fromarray(img.astype(np.uint8))
im.save("hacked-image.png")
# Out:
# Model's predicted likelihood that the image is a toaster: 0.0036770565%
# Model's predicted likelihood that the image is a toaster: 0.0036825691%
# Model's predicted likelihood that the image is a toaster: 0.0036880832%
# Model's predicted likelihood that the image is a toaster: 0.0036935999%
# Model's predicted likelihood that the image is a toaster: 0.0036991874%
# Model's predicted likelihood that the image is a toaster: 0.0037047786%
# Model's predicted likelihood that the image is a toaster: 0.0037103477%
# Model's predicted likelihood that the image is a toaster: 0.0037159847%
# Model's predicted likelihood that the image is a toaster: 0.0037216119%
# Model's predicted likelihood that the image is a toaster: 0.0037272712%
# Model's predicted likelihood that the image is a toaster: 0.0037329704%
# Model's predicted likelihood that the image is a toaster: 0.003738681%
# Model's predicted likelihood that the image is a toaster: 0.0037443715%
# Model's predicted likelihood that the image is a toaster: 0.0037500995%
# Model's predicted likelihood that the image is a toaster: 0.0037558235%
# Model's predicted likelihood that the image is a toaster: 0.0037615675%
# Model's predicted likelihood that the image is a toaster: 0.0037673355%
# Model's predicted likelihood that the image is a toaster: 0.0037730639%
# Model's predicted likelihood that the image is a toaster: 0.0037788366%
# Model's predicted likelihood that the image is a toaster: 0.0037846239%
# Model's predicted likelihood that the image is a toaster: 0.0037904123%
# Model's predicted likelihood that the image is a toaster: 0.0037962123%
# Model's predicted likelihood that the image is a toaster: 0.0038020615%
# Model's predicted likelihood that the image is a toaster: 0.0038079146%
# Model's predicted likelihood that the image is a toaster: 0.0038138296%
# Model's predicted likelihood that the image is a toaster: 0.0038197257%
# Model's predicted likelihood that the image is a toaster: 0.0038256629%
# Model's predicted likelihood that the image is a toaster: 0.0038316197%
# Model's predicted likelihood that the image is a toaster: 0.0038375514%
# Model's predicted likelihood that the image is a toaster: 0.0038435144%
# Model's predicted likelihood that the image is a toaster: 0.0038494927%
# Model's predicted likelihood that the image is a toaster: 0.0038554892%
# Model's predicted likelihood that the image is a toaster: 0.0038614387%
# Model's predicted likelihood that the image is a toaster: 0.0038674309%
# Model's predicted likelihood that the image is a toaster: 0.0038734699%
# Model's predicted likelihood that the image is a toaster: 0.003879526%
# Model's predicted likelihood that the image is a toaster: 0.0038855855%
# Model's predicted likelihood that the image is a toaster: 0.0038916907%
# Model's predicted likelihood that the image is a toaster: 0.0038977436%
# Model's predicted likelihood that the image is a toaster: 0.0039039118%
# Model's predicted likelihood that the image is a toaster: 0.003910044%
# Model's predicted likelihood that the image is a toaster: 0.0039161994%
# Model's predicted likelihood that the image is a toaster: 0.0039223392%
# Model's predicted likelihood that the image is a toaster: 0.0039285027%
# Model's predicted likelihood that the image is a toaster: 0.0039346971%
# Model's predicted likelihood that the image is a toaster: 0.0039409166%
# Model's predicted likelihood that the image is a toaster: 0.0039471404%
# Model's predicted likelihood that the image is a toaster: 0.0039533301%
# Model's predicted likelihood that the image is a toaster: 0.0039595787%
# Model's predicted likelihood that the image is a toaster: 0.0039658513%
# Model's predicted likelihood that the image is a toaster: 0.0039721584%
# Model's predicted likelihood that the image is a toaster: 0.0039784773%
# Model's predicted likelihood that the image is a toaster: 0.0039848383%
# Model's predicted likelihood that the image is a toaster: 0.0039912175%
# Model's predicted likelihood that the image is a toaster: 0.003997593%
# Model's predicted likelihood that the image is a toaster: 0.0040040097%
# Model's predicted likelihood that the image is a toaster: 0.0040104496%
# Model's predicted likelihood that the image is a toaster: 0.0040169263%
# Model's predicted likelihood that the image is a toaster: 0.0040234012%
# Model's predicted likelihood that the image is a toaster: 0.0040298797%
# Model's predicted likelihood that the image is a toaster: 0.004036376%
# Model's predicted likelihood that the image is a toaster: 0.0040428724%
# Model's predicted likelihood that the image is a toaster: 0.0040493709%
# Model's predicted likelihood that the image is a toaster: 0.004055908%
# Model's predicted likelihood that the image is a toaster: 0.0040624331%
# Model's predicted likelihood that the image is a toaster: 0.0040689829%
# Model's predicted likelihood that the image is a toaster: 0.0040755422%
# Model's predicted likelihood that the image is a toaster: 0.0040820938%
# Model's predicted likelihood that the image is a toaster: 0.0040886636%
# Model's predicted likelihood that the image is a toaster: 0.0040951953%
# Model's predicted likelihood that the image is a toaster: 0.0041017625%
# Model's predicted likelihood that the image is a toaster: 0.0041083258%
# Model's predicted likelihood that the image is a toaster: 0.0041149025%
# Model's predicted likelihood that the image is a toaster: 0.0041214742%
# Model's predicted likelihood that the image is a toaster: 0.0041280866%
# Model's predicted likelihood that the image is a toaster: 0.0041347172%
# Model's predicted likelihood that the image is a toaster: 0.0041413641%
# Model's predicted likelihood that the image is a toaster: 0.0041480329%
# Model's predicted likelihood that the image is a toaster: 0.0041547413%
# Model's predicted likelihood that the image is a toaster: 0.0041614843%
# Model's predicted likelihood that the image is a toaster: 0.0041682419%
# Model's predicted likelihood that the image is a toaster: 0.0041750183%
# Model's predicted likelihood that the image is a toaster: 0.0041818377%
# Model's predicted likelihood that the image is a toaster: 0.0041886517%
# Model's predicted likelihood that the image is a toaster: 0.0041954685%
# Model's predicted likelihood that the image is a toaster: 0.0042023021%
# Model's predicted likelihood that the image is a toaster: 0.0042091375%
# Model's predicted likelihood that the image is a toaster: 0.0042160093%
# Model's predicted likelihood that the image is a toaster: 0.0042229043%
# Model's predicted likelihood that the image is a toaster: 0.0042298241%
# Model's predicted likelihood that the image is a toaster: 0.0042367756%
# Model's predicted likelihood that the image is a toaster: 0.0042437296%
# Model's predicted likelihood that the image is a toaster: 0.0042506945%
# Model's predicted likelihood that the image is a toaster: 0.0042577514%
# Model's predicted likelihood that the image is a toaster: 0.0042648066%
# Model's predicted likelihood that the image is a toaster: 0.0042718624%
# Model's predicted likelihood that the image is a toaster: 0.0042789678%
# Model's predicted likelihood that the image is a toaster: 0.0042861368%
# Model's predicted likelihood that the image is a toaster: 0.0042933036%
# Model's predicted likelihood that the image is a toaster: 0.0043004969%
# Model's predicted likelihood that the image is a toaster: 0.004307702%
# Model's predicted likelihood that the image is a toaster: 0.0043148895%
# Model's predicted likelihood that the image is a toaster: 0.0043221313%
# Model's predicted likelihood that the image is a toaster: 0.0043293312%
# Model's predicted likelihood that the image is a toaster: 0.0043365584%
# Model's predicted likelihood that the image is a toaster: 0.0043437922%
# Model's predicted likelihood that the image is a toaster: 0.0043510296%
# Model's predicted likelihood that the image is a toaster: 0.0043582786%
# Model's predicted likelihood that the image is a toaster: 0.0043655673%
# Model's predicted likelihood that the image is a toaster: 0.0043728916%
# Model's predicted likelihood that the image is a toaster: 0.0043802029%
# Model's predicted likelihood that the image is a toaster: 0.0043875858%
# Model's predicted likelihood that the image is a toaster: 0.0043949854%
# Model's predicted likelihood that the image is a toaster: 0.0044024193%
# Model's predicted likelihood that the image is a toaster: 0.0044098695%
# Model's predicted likelihood that the image is a toaster: 0.0044173852%
# Model's predicted likelihood that the image is a toaster: 0.0044249289%
# Model's predicted likelihood that the image is a toaster: 0.0044324486%
# Model's predicted likelihood that the image is a toaster: 0.0044400196%
# Model's predicted likelihood that the image is a toaster: 0.0044476383%
# Model's predicted likelihood that the image is a toaster: 0.0044552624%
# Model's predicted likelihood that the image is a toaster: 0.0044629087%
# Model's predicted likelihood that the image is a toaster: 0.0044705339%
# Model's predicted likelihood that the image is a toaster: 0.0044781871%
# Model's predicted likelihood that the image is a toaster: 0.0044858618%
# Model's predicted likelihood that the image is a toaster: 0.0044935739%
# Model's predicted likelihood that the image is a toaster: 0.0045012071%
# Model's predicted likelihood that the image is a toaster: 0.00450886%
# Model's predicted likelihood that the image is a toaster: 0.0045165518%
# Model's predicted likelihood that the image is a toaster: 0.0045242683%
# Model's predicted likelihood that the image is a toaster: 0.0045320059%
# Model's predicted likelihood that the image is a toaster: 0.004539749%
# Model's predicted likelihood that the image is a toaster: 0.0045474742%
# Model's predicted likelihood that the image is a toaster: 0.0045552573%
# Model's predicted likelihood that the image is a toaster: 0.0045630597%
# Model's predicted likelihood that the image is a toaster: 0.0045708919%
# Model's predicted likelihood that the image is a toaster: 0.0045787234%
# Model's predicted likelihood that the image is a toaster: 0.0045865567%
# Model's predicted likelihood that the image is a toaster: 0.0045944533%
# Model's predicted likelihood that the image is a toaster: 0.004602367%
# Model's predicted likelihood that the image is a toaster: 0.0046102428%
# Model's predicted likelihood that the image is a toaster: 0.0046181787%
# Model's predicted likelihood that the image is a toaster: 0.0046261823%
# Model's predicted likelihood that the image is a toaster: 0.0046342171%
# Model's predicted likelihood that the image is a toaster: 0.004642272%
# Model's predicted likelihood that the image is a toaster: 0.0046503625%
# Model's predicted likelihood that the image is a toaster: 0.0046585144%
# Model's predicted likelihood that the image is a toaster: 0.0046666777%
# Model's predicted likelihood that the image is a toaster: 0.0046748646%
# Model's predicted likelihood that the image is a toaster: 0.0046830843%
# Model's predicted likelihood that the image is a toaster: 0.0046913221%
# Model's predicted likelihood that the image is a toaster: 0.0046995385%
# Model's predicted likelihood that the image is a toaster: 0.0047077709%
# Model's predicted likelihood that the image is a toaster: 0.0047159923%
# Model's predicted likelihood that the image is a toaster: 0.0047242989%
# Model's predicted likelihood that the image is a toaster: 0.0047325957%
# Model's predicted likelihood that the image is a toaster: 0.0047409118%
# Model's predicted likelihood that the image is a toaster: 0.0047492638%
# Model's predicted likelihood that the image is a toaster: 0.0047577007%
# Model's predicted likelihood that the image is a toaster: 0.0047661269%
# Model's predicted likelihood that the image is a toaster: 0.0047746147%
# Model's predicted likelihood that the image is a toaster: 0.0047831392%
# Model's predicted likelihood that the image is a toaster: 0.0047916477%
# Model's predicted likelihood that the image is a toaster: 0.004800177%
# Model's predicted likelihood that the image is a toaster: 0.0048087135%
# Model's predicted likelihood that the image is a toaster: 0.0048173053%
# Model's predicted likelihood that the image is a toaster: 0.0048259717%
# Model's predicted likelihood that the image is a toaster: 0.0048346825%
# Model's predicted likelihood that the image is a toaster: 0.0048433172%
# Model's predicted likelihood that the image is a toaster: 0.0048519691%
# Model's predicted likelihood that the image is a toaster: 0.0048606147%
# Model's predicted likelihood that the image is a toaster: 0.0048693211%
# Model's predicted likelihood that the image is a toaster: 0.0048780192%
# Model's predicted likelihood that the image is a toaster: 0.0048867452%
# Model's predicted likelihood that the image is a toaster: 0.0048955088%
# Model's predicted likelihood that the image is a toaster: 0.0049043472%
# Model's predicted likelihood that the image is a toaster: 0.0049132403%
# Model's predicted likelihood that the image is a toaster: 0.0049221875%
# Model's predicted likelihood that the image is a toaster: 0.0049310951%
# Model's predicted likelihood that the image is a toaster: 0.0049400624%
# Model's predicted likelihood that the image is a toaster: 0.0049490285%
# Model's predicted likelihood that the image is a toaster: 0.0049580744%
# Model's predicted likelihood that the image is a toaster: 0.0049671187%
# Model's predicted likelihood that the image is a toaster: 0.0049761722%
# Model's predicted likelihood that the image is a toaster: 0.0049852468%
# Model's predicted likelihood that the image is a toaster: 0.0049943323%
# Model's predicted likelihood that the image is a toaster: 0.0050034028%
# Model's predicted likelihood that the image is a toaster: 0.0050125207%
# Model's predicted likelihood that the image is a toaster: 0.005021556%
# Model's predicted likelihood that the image is a toaster: 0.0050306673%
# Model's predicted likelihood that the image is a toaster: 0.0050398445%
# Model's predicted likelihood that the image is a toaster: 0.0050490074%
# Model's predicted likelihood that the image is a toaster: 0.0050582792%
# Model's predicted likelihood that the image is a toaster: 0.0050675597%
# Model's predicted likelihood that the image is a toaster: 0.0050768958%
# Model's predicted likelihood that the image is a toaster: 0.0050862283%
# Model's predicted likelihood that the image is a toaster: 0.0050955237%
# Model's predicted likelihood that the image is a toaster: 0.0051048592%
# Model's predicted likelihood that the image is a toaster: 0.0051142713%
# Model's predicted likelihood that the image is a toaster: 0.0051236817%
# Model's predicted likelihood that the image is a toaster: 0.0051331834%
# Model's predicted likelihood that the image is a toaster: 0.0051426148%
# Model's predicted likelihood that the image is a toaster: 0.0051520979%
# Model's predicted likelihood that the image is a toaster: 0.005161628%
# Model's predicted likelihood that the image is a toaster: 0.005171165%
# Model's predicted likelihood that the image is a toaster: 0.0051806899%
# Model's predicted likelihood that the image is a toaster: 0.0051902593%
# Model's predicted likelihood that the image is a toaster: 0.0051998952%
# Model's predicted likelihood that the image is a toaster: 0.0052095536%
# Model's predicted likelihood that the image is a toaster: 0.0052192849%
# Model's predicted likelihood that the image is a toaster: 0.0052289772%
# Model's predicted likelihood that the image is a toaster: 0.0052387455%
# Model's predicted likelihood that the image is a toaster: 0.0052485699%
# Model's predicted likelihood that the image is a toaster: 0.0052584004%
# Model's predicted likelihood that the image is a toaster: 0.0052681902%
# Model's predicted likelihood that the image is a toaster: 0.0052780528%
# Model's predicted likelihood that the image is a toaster: 0.0052879088%
# Model's predicted likelihood that the image is a toaster: 0.0052978208%
# Model's predicted likelihood that the image is a toaster: 0.0053078184%
# Model's predicted likelihood that the image is a toaster: 0.0053178166%
# Model's predicted likelihood that the image is a toaster: 0.0053278451%
# Model's predicted likelihood that the image is a toaster: 0.0053379557%
# Model's predicted likelihood that the image is a toaster: 0.0053481228%
# Model's predicted likelihood that the image is a toaster: 0.0053582778%
# Model's predicted likelihood that the image is a toaster: 0.0053684489%
# Model's predicted likelihood that the image is a toaster: 0.0053785949%
# Model's predicted likelihood that the image is a toaster: 0.0053888667%
# Model's predicted likelihood that the image is a toaster: 0.0053991429%
# Model's predicted likelihood that the image is a toaster: 0.0054095053%
# Model's predicted likelihood that the image is a toaster: 0.0054198954%
# Model's predicted likelihood that the image is a toaster: 0.0054303087%
# Model's predicted likelihood that the image is a toaster: 0.0054406763%
# Model's predicted likelihood that the image is a toaster: 0.005451071%
# Model's predicted likelihood that the image is a toaster: 0.0054614866%
# Model's predicted likelihood that the image is a toaster: 0.0054719232%
# Model's predicted likelihood that the image is a toaster: 0.0054823147%
# Model's predicted likelihood that the image is a toaster: 0.0054927685%
# Model's predicted likelihood that the image is a toaster: 0.0055032404%
# Model's predicted likelihood that the image is a toaster: 0.0055137622%
# Model's predicted likelihood that the image is a toaster: 0.0055243177%
# Model's predicted likelihood that the image is a toaster: 0.0055348573%
# Model's predicted likelihood that the image is a toaster: 0.0055454519%
# Model's predicted likelihood that the image is a toaster: 0.0055561839%
# Model's predicted likelihood that the image is a toaster: 0.0055668748%
# Model's predicted likelihood that the image is a toaster: 0.0055776291%
# Model's predicted likelihood that the image is a toaster: 0.0055884233%
# Model's predicted likelihood that the image is a toaster: 0.0055992732%
# Model's predicted likelihood that the image is a toaster: 0.0056102039%
# Model's predicted likelihood that the image is a toaster: 0.0056211571%
# Model's predicted likelihood that the image is a toaster: 0.0056321256%
# Model's predicted likelihood that the image is a toaster: 0.0056431058%
# Model's predicted likelihood that the image is a toaster: 0.0056541463%
# Model's predicted likelihood that the image is a toaster: 0.0056652698%
# Model's predicted likelihood that the image is a toaster: 0.0056764231%
# Model's predicted likelihood that the image is a toaster: 0.0056876583%
# Model's predicted likelihood that the image is a toaster: 0.0056989789%
# Model's predicted likelihood that the image is a toaster: 0.0057103643%
# Model's predicted likelihood that the image is a toaster: 0.0057218858%
# Model's predicted likelihood that the image is a toaster: 0.0057334077%
# Model's predicted likelihood that the image is a toaster: 0.0057449932%
# Model's predicted likelihood that the image is a toaster: 0.005756594%
# Model's predicted likelihood that the image is a toaster: 0.005768178%
# Model's predicted likelihood that the image is a toaster: 0.0057797708%
# Model's predicted likelihood that the image is a toaster: 0.005791377%
# Model's predicted likelihood that the image is a toaster: 0.0058029789%
# Model's predicted likelihood that the image is a toaster: 0.0058145251%
# Model's predicted likelihood that the image is a toaster: 0.005826151%
# Model's predicted likelihood that the image is a toaster: 0.005837866%
# Model's predicted likelihood that the image is a toaster: 0.0058495483%
# Model's predicted likelihood that the image is a toaster: 0.0058611822%
# Model's predicted likelihood that the image is a toaster: 0.005872799%
# Model's predicted likelihood that the image is a toaster: 0.0058843503%
# Model's predicted likelihood that the image is a toaster: 0.0058960348%
# Model's predicted likelihood that the image is a toaster: 0.0059077312%
# Model's predicted likelihood that the image is a toaster: 0.005919479%
# Model's predicted likelihood that the image is a toaster: 0.0059312231%
# Model's predicted likelihood that the image is a toaster: 0.0059430877%
# Model's predicted likelihood that the image is a toaster: 0.0059549202%
# Model's predicted likelihood that the image is a toaster: 0.0059667898%
# Model's predicted likelihood that the image is a toaster: 0.0059786631%
# Model's predicted likelihood that the image is a toaster: 0.0059905207%
# Model's predicted likelihood that the image is a toaster: 0.0060023554%
# Model's predicted likelihood that the image is a toaster: 0.0060142429%
# Model's predicted likelihood that the image is a toaster: 0.006026114%
# Model's predicted likelihood that the image is a toaster: 0.0060380913%
# Model's predicted likelihood that the image is a toaster: 0.0060500566%
# Model's predicted likelihood that the image is a toaster: 0.0060621191%
# Model's predicted likelihood that the image is a toaster: 0.0060742339%
# Model's predicted likelihood that the image is a toaster: 0.0060863957%
# Model's predicted likelihood that the image is a toaster: 0.0060985738%
# Model's predicted likelihood that the image is a toaster: 0.0061106948%
# Model's predicted likelihood that the image is a toaster: 0.0061229919%
# Model's predicted likelihood that the image is a toaster: 0.0061353196%
# Model's predicted likelihood that the image is a toaster: 0.0061476792%
# Model's predicted likelihood that the image is a toaster: 0.0061601408%
# Model's predicted likelihood that the image is a toaster: 0.006172611%
# Model's predicted likelihood that the image is a toaster: 0.0061851752%
# Model's predicted likelihood that the image is a toaster: 0.0061977735%
# Model's predicted likelihood that the image is a toaster: 0.0062104358%
# Model's predicted likelihood that the image is a toaster: 0.0062231979%
# Model's predicted likelihood that the image is a toaster: 0.0062359766%
# Model's predicted likelihood that the image is a toaster: 0.0062487372%
# Model's predicted likelihood that the image is a toaster: 0.0062615181%
# Model's predicted likelihood that the image is a toaster: 0.006274342%
# Model's predicted likelihood that the image is a toaster: 0.0062872539%
# Model's predicted likelihood that the image is a toaster: 0.0063001564%
# Model's predicted likelihood that the image is a toaster: 0.0063130719%
# Model's predicted likelihood that the image is a toaster: 0.006326002%
# Model's predicted likelihood that the image is a toaster: 0.0063390216%
# Model's predicted likelihood that the image is a toaster: 0.0063520674%
# Model's predicted likelihood that the image is a toaster: 0.006365186%
# Model's predicted likelihood that the image is a toaster: 0.0063783402%
# Model's predicted likelihood that the image is a toaster: 0.0063914769%
# Model's predicted likelihood that the image is a toaster: 0.0064046522%
# Model's predicted likelihood that the image is a toaster: 0.0064179621%
# Model's predicted likelihood that the image is a toaster: 0.0064313863%
# Model's predicted likelihood that the image is a toaster: 0.0064448621%
# Model's predicted likelihood that the image is a toaster: 0.0064584223%
# Model's predicted likelihood that the image is a toaster: 0.0064720502%
# Model's predicted likelihood that the image is a toaster: 0.0064857188%
# Model's predicted likelihood that the image is a toaster: 0.0064994812%
# Model's predicted likelihood that the image is a toaster: 0.0065132786%
# Model's predicted likelihood that the image is a toaster: 0.0065271422%
# Model's predicted likelihood that the image is a toaster: 0.0065410743%
# Model's predicted likelihood that the image is a toaster: 0.0065550332%
# Model's predicted likelihood that the image is a toaster: 0.0065690198%
# Model's predicted likelihood that the image is a toaster: 0.0065830136%
# Model's predicted likelihood that the image is a toaster: 0.0065969667%
# Model's predicted likelihood that the image is a toaster: 0.0066109751%
# Model's predicted likelihood that the image is a toaster: 0.006624969%
# Model's predicted likelihood that the image is a toaster: 0.0066389839%
# Model's predicted likelihood that the image is a toaster: 0.0066531%
# Model's predicted likelihood that the image is a toaster: 0.0066672357%
# Model's predicted likelihood that the image is a toaster: 0.0066814195%
# Model's predicted likelihood that the image is a toaster: 0.0066956665%
# Model's predicted likelihood that the image is a toaster: 0.0067099914%
# Model's predicted likelihood that the image is a toaster: 0.0067244728%
# Model's predicted likelihood that the image is a toaster: 0.0067389446%
# Model's predicted likelihood that the image is a toaster: 0.0067534915%
# Model's predicted likelihood that the image is a toaster: 0.0067681292%
# Model's predicted likelihood that the image is a toaster: 0.0067828078%
# Model's predicted likelihood that the image is a toaster: 0.0067975059%
# Model's predicted likelihood that the image is a toaster: 0.0068121844%
# Model's predicted likelihood that the image is a toaster: 0.0068267887%
# Model's predicted likelihood that the image is a toaster: 0.0068413872%
# Model's predicted likelihood that the image is a toaster: 0.0068560264%
# Model's predicted likelihood that the image is a toaster: 0.0068707108%
# Model's predicted likelihood that the image is a toaster: 0.0068854053%
# Model's predicted likelihood that the image is a toaster: 0.0069001311%
# Model's predicted likelihood that the image is a toaster: 0.0069148642%
# Model's predicted likelihood that the image is a toaster: 0.0069296126%
# Model's predicted likelihood that the image is a toaster: 0.0069442925%
# Model's predicted likelihood that the image is a toaster: 0.0069590918%
# Model's predicted likelihood that the image is a toaster: 0.0069738708%
# Model's predicted likelihood that the image is a toaster: 0.0069886606%
# Model's predicted likelihood that the image is a toaster: 0.0070035101%
# Model's predicted likelihood that the image is a toaster: 0.0070183036%
# Model's predicted likelihood that the image is a toaster: 0.0070331203%
# Model's predicted likelihood that the image is a toaster: 0.0070481328%
# Model's predicted likelihood that the image is a toaster: 0.0070631984%
# Model's predicted likelihood that the image is a toaster: 0.0070782866%
# Model's predicted likelihood that the image is a toaster: 0.0070934853%
# Model's predicted likelihood that the image is a toaster: 0.0071086804%
# Model's predicted likelihood that the image is a toaster: 0.0071239527%
# Model's predicted likelihood that the image is a toaster: 0.007139206%
# Model's predicted likelihood that the image is a toaster: 0.0071545248%
# Model's predicted likelihood that the image is a toaster: 0.0071697825%
# Model's predicted likelihood that the image is a toaster: 0.0071851333%
# Model's predicted likelihood that the image is a toaster: 0.0072005234%
# Model's predicted likelihood that the image is a toaster: 0.0072159019%
# Model's predicted likelihood that the image is a toaster: 0.007231356%
# Model's predicted likelihood that the image is a toaster: 0.0072469484%
# Model's predicted likelihood that the image is a toaster: 0.007262631%
# Model's predicted likelihood that the image is a toaster: 0.0072783594%
# Model's predicted likelihood that the image is a toaster: 0.0072941461%
# Model's predicted likelihood that the image is a toaster: 0.0073100186%
# Model's predicted likelihood that the image is a toaster: 0.0073259667%
# Model's predicted likelihood that the image is a toaster: 0.0073419345%
# Model's predicted likelihood that the image is a toaster: 0.0073579708%
# Model's predicted likelihood that the image is a toaster: 0.0073740426%
# Model's predicted likelihood that the image is a toaster: 0.007390169%
# Model's predicted likelihood that the image is a toaster: 0.0074063704%
# Model's predicted likelihood that the image is a toaster: 0.0074226984%
# Model's predicted likelihood that the image is a toaster: 0.0074392592%
# Model's predicted likelihood that the image is a toaster: 0.0074559437%
# Model's predicted likelihood that the image is a toaster: 0.0074726835%
# Model's predicted likelihood that the image is a toaster: 0.0074895106%
# Model's predicted likelihood that the image is a toaster: 0.0075063355%
# Model's predicted likelihood that the image is a toaster: 0.0075232347%
# Model's predicted likelihood that the image is a toaster: 0.007540144%
# Model's predicted likelihood that the image is a toaster: 0.0075571937%
# Model's predicted likelihood that the image is a toaster: 0.0075744734%
# Model's predicted likelihood that the image is a toaster: 0.0075919474%
# Model's predicted likelihood that the image is a toaster: 0.0076094671%
# Model's predicted likelihood that the image is a toaster: 0.0076270553%
# Model's predicted likelihood that the image is a toaster: 0.0076447905%
# Model's predicted likelihood that the image is a toaster: 0.0076627031%
# Model's predicted likelihood that the image is a toaster: 0.0076807315%
# Model's predicted likelihood that the image is a toaster: 0.0076987686%
# Model's predicted likelihood that the image is a toaster: 0.0077168275%
# Model's predicted likelihood that the image is a toaster: 0.0077348421%
# Model's predicted likelihood that the image is a toaster: 0.00775304%
# Model's predicted likelihood that the image is a toaster: 0.0077713543%
# Model's predicted likelihood that the image is a toaster: 0.0077897712%
# Model's predicted likelihood that the image is a toaster: 0.0078083118%
# Model's predicted likelihood that the image is a toaster: 0.0078269099%
# Model's predicted likelihood that the image is a toaster: 0.007845636%
# Model's predicted likelihood that the image is a toaster: 0.007864384%
# Model's predicted likelihood that the image is a toaster: 0.0078832381%
# Model's predicted likelihood that the image is a toaster: 0.0079021294%
# Model's predicted likelihood that the image is a toaster: 0.0079211524%
# Model's predicted likelihood that the image is a toaster: 0.0079402314%
# Model's predicted likelihood that the image is a toaster: 0.0079595535%
# Model's predicted likelihood that the image is a toaster: 0.0079788326%
# Model's predicted likelihood that the image is a toaster: 0.0079981648%
# Model's predicted likelihood that the image is a toaster: 0.0080176316%
# Model's predicted likelihood that the image is a toaster: 0.0080372592%
# Model's predicted likelihood that the image is a toaster: 0.0080569618%
# Model's predicted likelihood that the image is a toaster: 0.0080767815%
# Model's predicted likelihood that the image is a toaster: 0.0080967642%
# Model's predicted likelihood that the image is a toaster: 0.0081168801%
# Model's predicted likelihood that the image is a toaster: 0.0081368831%
# Model's predicted likelihood that the image is a toaster: 0.008156884%
# Model's predicted likelihood that the image is a toaster: 0.0081770653%
# Model's predicted likelihood that the image is a toaster: 0.0081974307%
# Model's predicted likelihood that the image is a toaster: 0.0082179569%
# Model's predicted likelihood that the image is a toaster: 0.0082386978%
# Model's predicted likelihood that the image is a toaster: 0.0082594226%
# Model's predicted likelihood that the image is a toaster: 0.0082801984%
# Model's predicted likelihood that the image is a toaster: 0.0083010127%
# Model's predicted likelihood that the image is a toaster: 0.0083217463%
# Model's predicted likelihood that the image is a toaster: 0.0083426596%
# Model's predicted likelihood that the image is a toaster: 0.0083636638%
# Model's predicted likelihood that the image is a toaster: 0.0083848325%
# Model's predicted likelihood that the image is a toaster: 0.008405991%
# Model's predicted likelihood that the image is a toaster: 0.0084273357%
# Model's predicted likelihood that the image is a toaster: 0.0084487285%
# Model's predicted likelihood that the image is a toaster: 0.0084702966%
# Model's predicted likelihood that the image is a toaster: 0.0084918611%
# Model's predicted likelihood that the image is a toaster: 0.0085135085%
# Model's predicted likelihood that the image is a toaster: 0.0085352345%
# Model's predicted likelihood that the image is a toaster: 0.0085570726%
# Model's predicted likelihood that the image is a toaster: 0.0085791093%
# Model's predicted likelihood that the image is a toaster: 0.0086013315%
# Model's predicted likelihood that the image is a toaster: 0.0086235414%
# Model's predicted likelihood that the image is a toaster: 0.0086458393%
# Model's predicted likelihood that the image is a toaster: 0.0086683118%
# Model's predicted likelihood that the image is a toaster: 0.0086907043%
# Model's predicted likelihood that the image is a toaster: 0.008713211%
# Model's predicted likelihood that the image is a toaster: 0.0087358385%
# Model's predicted likelihood that the image is a toaster: 0.0087586108%
# Model's predicted likelihood that the image is a toaster: 0.0087812703%
# Model's predicted likelihood that the image is a toaster: 0.0088039509%
# Model's predicted likelihood that the image is a toaster: 0.0088267894%
# Model's predicted likelihood that the image is a toaster: 0.0088496134%
# Model's predicted likelihood that the image is a toaster: 0.0088726018%
# Model's predicted likelihood that the image is a toaster: 0.0088955676%
# Model's predicted likelihood that the image is a toaster: 0.0089186913%
# Model's predicted likelihood that the image is a toaster: 0.0089419053%
# Model's predicted likelihood that the image is a toaster: 0.0089651192%
# Model's predicted likelihood that the image is a toaster: 0.0089884619%
# Model's predicted likelihood that the image is a toaster: 0.0090118941%
# Model's predicted likelihood that the image is a toaster: 0.0090353969%
# Model's predicted likelihood that the image is a toaster: 0.0090589412%
# Model's predicted likelihood that the image is a toaster: 0.0090826332%
# Model's predicted likelihood that the image is a toaster: 0.0091063281%
# Model's predicted likelihood that the image is a toaster: 0.0091301998%
# Model's predicted likelihood that the image is a toaster: 0.009154086%
# Model's predicted likelihood that the image is a toaster: 0.0091779788%
# Model's predicted likelihood that the image is a toaster: 0.0092020084%
# Model's predicted likelihood that the image is a toaster: 0.0092261456%
# Model's predicted likelihood that the image is a toaster: 0.0092503135%
# Model's predicted likelihood that the image is a toaster: 0.0092746632%
# Model's predicted likelihood that the image is a toaster: 0.0092989983%
# Model's predicted likelihood that the image is a toaster: 0.0093233713%
# Model's predicted likelihood that the image is a toaster: 0.0093478717%
# Model's predicted likelihood that the image is a toaster: 0.0093725728%
# Model's predicted likelihood that the image is a toaster: 0.0093974595%
# Model's predicted likelihood that the image is a toaster: 0.0094225019%
# Model's predicted likelihood that the image is a toaster: 0.0094475807%
# Model's predicted likelihood that the image is a toaster: 0.0094728603%
# Model's predicted likelihood that the image is a toaster: 0.0094983159%
# Model's predicted likelihood that the image is a toaster: 0.0095239237%
# Model's predicted likelihood that the image is a toaster: 0.0095496092%
# Model's predicted likelihood that the image is a toaster: 0.0095753334%
# Model's predicted likelihood that the image is a toaster: 0.0096011921%
# Model's predicted likelihood that the image is a toaster: 0.0096270458%
# Model's predicted likelihood that the image is a toaster: 0.0096531236%
# Model's predicted likelihood that the image is a toaster: 0.0096795855%
# Model's predicted likelihood that the image is a toaster: 0.0097060787%
# Model's predicted likelihood that the image is a toaster: 0.0097326105%
# Model's predicted likelihood that the image is a toaster: 0.0097592427%
# Model's predicted likelihood that the image is a toaster: 0.0097861441%
# Model's predicted likelihood that the image is a toaster: 0.0098134777%
# Model's predicted likelihood that the image is a toaster: 0.0098410739%
# Model's predicted likelihood that the image is a toaster: 0.009868871%
# Model's predicted likelihood that the image is a toaster: 0.0098968245%
# Model's predicted likelihood that the image is a toaster: 0.0099247314%
# Model's predicted likelihood that the image is a toaster: 0.0099527177%
# Model's predicted likelihood that the image is a toaster: 0.009980888%
# Model's predicted likelihood that the image is a toaster: 0.010009021%
# Model's predicted likelihood that the image is a toaster: 0.010037443%
# Model's predicted likelihood that the image is a toaster: 0.010065888%
# Model's predicted likelihood that the image is a toaster: 0.010094574%
# Model's predicted likelihood that the image is a toaster: 0.010123188%
# Model's predicted likelihood that the image is a toaster: 0.010151917%
# Model's predicted likelihood that the image is a toaster: 0.010180775%
# Model's predicted likelihood that the image is a toaster: 0.010209688%
# Model's predicted likelihood that the image is a toaster: 0.010238849%
# Model's predicted likelihood that the image is a toaster: 0.010268204%
# Model's predicted likelihood that the image is a toaster: 0.010297712%
# Model's predicted likelihood that the image is a toaster: 0.010327133%
# Model's predicted likelihood that the image is a toaster: 0.010356613%
# Model's predicted likelihood that the image is a toaster: 0.010386307%
# Model's predicted likelihood that the image is a toaster: 0.010416188%
# Model's predicted likelihood that the image is a toaster: 0.01044622%
# Model's predicted likelihood that the image is a toaster: 0.010476292%
# Model's predicted likelihood that the image is a toaster: 0.010506486%
# Model's predicted likelihood that the image is a toaster: 0.010536931%
# Model's predicted likelihood that the image is a toaster: 0.0105675%
# Model's predicted likelihood that the image is a toaster: 0.010598016%
# Model's predicted likelihood that the image is a toaster: 0.010628934%
# Model's predicted likelihood that the image is a toaster: 0.010659958%
# Model's predicted likelihood that the image is a toaster: 0.01069108%
# Model's predicted likelihood that the image is a toaster: 0.010722399%
# Model's predicted likelihood that the image is a toaster: 0.010753905%
# Model's predicted likelihood that the image is a toaster: 0.010785484%
# Model's predicted likelihood that the image is a toaster: 0.010817248%
# Model's predicted likelihood that the image is a toaster: 0.010849293%
# Model's predicted likelihood that the image is a toaster: 0.010881401%
# Model's predicted likelihood that the image is a toaster: 0.010913525%
# Model's predicted likelihood that the image is a toaster: 0.010945869%
# Model's predicted likelihood that the image is a toaster: 0.010978404%
# Model's predicted likelihood that the image is a toaster: 0.011010735%
# Model's predicted likelihood that the image is a toaster: 0.011043272%
# Model's predicted likelihood that the image is a toaster: 0.011075856%
# Model's predicted likelihood that the image is a toaster: 0.011108683%
# Model's predicted likelihood that the image is a toaster: 0.01114189%
# Model's predicted likelihood that the image is a toaster: 0.011175189%
# Model's predicted likelihood that the image is a toaster: 0.011208533%
# Model's predicted likelihood that the image is a toaster: 0.011242113%
# Model's predicted likelihood that the image is a toaster: 0.011276028%
# Model's predicted likelihood that the image is a toaster: 0.011310173%
# Model's predicted likelihood that the image is a toaster: 0.011344827%
# Model's predicted likelihood that the image is a toaster: 0.011379478%
# Model's predicted likelihood that the image is a toaster: 0.011414107%
# Model's predicted likelihood that the image is a toaster: 0.011448823%
# Model's predicted likelihood that the image is a toaster: 0.011483679%
# Model's predicted likelihood that the image is a toaster: 0.011518715%
# Model's predicted likelihood that the image is a toaster: 0.011553983%
# Model's predicted likelihood that the image is a toaster: 0.011589284%
# Model's predicted likelihood that the image is a toaster: 0.011624564%
# Model's predicted likelihood that the image is a toaster: 0.011660002%
# Model's predicted likelihood that the image is a toaster: 0.011695589%
# Model's predicted likelihood that the image is a toaster: 0.011731282%
# Model's predicted likelihood that the image is a toaster: 0.011767024%
# Model's predicted likelihood that the image is a toaster: 0.011803105%
# Model's predicted likelihood that the image is a toaster: 0.011839477%
# Model's predicted likelihood that the image is a toaster: 0.011876176%
# Model's predicted likelihood that the image is a toaster: 0.011912855%
# Model's predicted likelihood that the image is a toaster: 0.011949537%
# Model's predicted likelihood that the image is a toaster: 0.01198672%
# Model's predicted likelihood that the image is a toaster: 0.0120239%
# Model's predicted likelihood that the image is a toaster: 0.0120612%
# Model's predicted likelihood that the image is a toaster: 0.012098547%
# Model's predicted likelihood that the image is a toaster: 0.012136195%
# Model's predicted likelihood that the image is a toaster: 0.012174159%
# Model's predicted likelihood that the image is a toaster: 0.012212333%
# Model's predicted likelihood that the image is a toaster: 0.012250541%
# Model's predicted likelihood that the image is a toaster: 0.01228902%
# Model's predicted likelihood that the image is a toaster: 0.012327546%
# Model's predicted likelihood that the image is a toaster: 0.012366041%
# Model's predicted likelihood that the image is a toaster: 0.012404754%
# Model's predicted likelihood that the image is a toaster: 0.012443631%
# Model's predicted likelihood that the image is a toaster: 0.012482519%
# Model's predicted likelihood that the image is a toaster: 0.012521856%
# Model's predicted likelihood that the image is a toaster: 0.012561592%
# Model's predicted likelihood that the image is a toaster: 0.012601582%
# Model's predicted likelihood that the image is a toaster: 0.01264179%
# Model's predicted likelihood that the image is a toaster: 0.012682362%
# Model's predicted likelihood that the image is a toaster: 0.012722763%
# Model's predicted likelihood that the image is a toaster: 0.012763652%
# Model's predicted likelihood that the image is a toaster: 0.012804785%
# Model's predicted likelihood that the image is a toaster: 0.012846122%
# Model's predicted likelihood that the image is a toaster: 0.012887477%
# Model's predicted likelihood that the image is a toaster: 0.012928771%
# Model's predicted likelihood that the image is a toaster: 0.012970397%
# Model's predicted likelihood that the image is a toaster: 0.013012171%
# Model's predicted likelihood that the image is a toaster: 0.013054311%
# Model's predicted likelihood that the image is a toaster: 0.013096779%
# Model's predicted likelihood that the image is a toaster: 0.0131391%
# Model's predicted likelihood that the image is a toaster: 0.013181873%
# Model's predicted likelihood that the image is a toaster: 0.013224695%
# Model's predicted likelihood that the image is a toaster: 0.013268179%
# Model's predicted likelihood that the image is a toaster: 0.013311912%
# Model's predicted likelihood that the image is a toaster: 0.013356151%
# Model's predicted likelihood that the image is a toaster: 0.013400699%
# Model's predicted likelihood that the image is a toaster: 0.013445548%
# Model's predicted likelihood that the image is a toaster: 0.013490762%
# Model's predicted likelihood that the image is a toaster: 0.013536154%
# Model's predicted likelihood that the image is a toaster: 0.013581743%
# Model's predicted likelihood that the image is a toaster: 0.013627882%
# Model's predicted likelihood that the image is a toaster: 0.013674045%
# Model's predicted likelihood that the image is a toaster: 0.013720525%
# Model's predicted likelihood that the image is a toaster: 0.013767203%
# Model's predicted likelihood that the image is a toaster: 0.013814143%
# Model's predicted likelihood that the image is a toaster: 0.013861252%
# Model's predicted likelihood that the image is a toaster: 0.013908623%
# Model's predicted likelihood that the image is a toaster: 0.013956444%
# Model's predicted likelihood that the image is a toaster: 0.014005018%
# Model's predicted likelihood that the image is a toaster: 0.014053889%
# Model's predicted likelihood that the image is a toaster: 0.014103297%
# Model's predicted likelihood that the image is a toaster: 0.014152976%
# Model's predicted likelihood that the image is a toaster: 0.014202896%
# Model's predicted likelihood that the image is a toaster: 0.014252758%
# Model's predicted likelihood that the image is a toaster: 0.014302891%
# Model's predicted likelihood that the image is a toaster: 0.014353618%
# Model's predicted likelihood that the image is a toaster: 0.01440507%
# Model's predicted likelihood that the image is a toaster: 0.014456581%
# Model's predicted likelihood that the image is a toaster: 0.014508095%
# Model's predicted likelihood that the image is a toaster: 0.014559718%
# Model's predicted likelihood that the image is a toaster: 0.014611518%
# Model's predicted likelihood that the image is a toaster: 0.014663734%
# Model's predicted likelihood that the image is a toaster: 0.014717079%
# Model's predicted likelihood that the image is a toaster: 0.014770679%
# Model's predicted likelihood that the image is a toaster: 0.014824765%
# Model's predicted likelihood that the image is a toaster: 0.014878772%
# Model's predicted likelihood that the image is a toaster: 0.014932554%
# Model's predicted likelihood that the image is a toaster: 0.014986866%
# Model's predicted likelihood that the image is a toaster: 0.01504149%
# Model's predicted likelihood that the image is a toaster: 0.015096275%
# Model's predicted likelihood that the image is a toaster: 0.015151549%
# Model's predicted likelihood that the image is a toaster: 0.015207079%
# Model's predicted likelihood that the image is a toaster: 0.015263149%
# Model's predicted likelihood that the image is a toaster: 0.01531974%
# Model's predicted likelihood that the image is a toaster: 0.015376724%
# Model's predicted likelihood that the image is a toaster: 0.015433824%
# Model's predicted likelihood that the image is a toaster: 0.015491183%
# Model's predicted likelihood that the image is a toaster: 0.015548532%
# Model's predicted likelihood that the image is a toaster: 0.015606591%
# Model's predicted likelihood that the image is a toaster: 0.015664716%
# Model's predicted likelihood that the image is a toaster: 0.015723155%
# Model's predicted likelihood that the image is a toaster: 0.01578174%
# Model's predicted likelihood that the image is a toaster: 0.015840486%
# Model's predicted likelihood that the image is a toaster: 0.015899674%
# Model's predicted likelihood that the image is a toaster: 0.015959299%
# Model's predicted likelihood that the image is a toaster: 0.016019311%
# Model's predicted likelihood that the image is a toaster: 0.016079491%
# Model's predicted likelihood that the image is a toaster: 0.016139887%
# Model's predicted likelihood that the image is a toaster: 0.016200365%
# Model's predicted likelihood that the image is a toaster: 0.016261065%
# Model's predicted likelihood that the image is a toaster: 0.016321774%
# Model's predicted likelihood that the image is a toaster: 0.01638336%
# Model's predicted likelihood that the image is a toaster: 0.016445262%
# Model's predicted likelihood that the image is a toaster: 0.016507407%
# Model's predicted likelihood that the image is a toaster: 0.016569511%
# Model's predicted likelihood that the image is a toaster: 0.016632224%
# Model's predicted likelihood that the image is a toaster: 0.016695239%
# Model's predicted likelihood that the image is a toaster: 0.016757894%
# Model's predicted likelihood that the image is a toaster: 0.016820998%
# Model's predicted likelihood that the image is a toaster: 0.016884205%
# Model's predicted likelihood that the image is a toaster: 0.016947836%
# Model's predicted likelihood that the image is a toaster: 0.017011246%
# Model's predicted likelihood that the image is a toaster: 0.017075142%
# Model's predicted likelihood that the image is a toaster: 0.017139601%
# Model's predicted likelihood that the image is a toaster: 0.017204309%
# Model's predicted likelihood that the image is a toaster: 0.017269209%
# Model's predicted likelihood that the image is a toaster: 0.017334272%
# Model's predicted likelihood that the image is a toaster: 0.017399025%
# ...
# Model's predicted likelihood that the image is a toaster: 0.040103306%
# Model's predicted likelihood that the image is a toaster: 0.040301419%
# Model's predicted likelihood that the image is a toaster: 0.040501732%
# Model's predicted likelihood that the image is a toaster: 0.040705164%
# Model's predicted likelihood that the image is a toaster: 0.04091252%
# Model's predicted likelihood that the image is a toaster: 0.041130642%
# Model's predicted likelihood that the image is a toaster: 0.041349515%
# Model's predicted likelihood that the image is a toaster: 0.041570971%
# Model's predicted likelihood that the image is a toaster: 0.041796241%
# Model's predicted likelihood that the image is a toaster: 0.042031167%
# Model's predicted likelihood that the image is a toaster: 0.042273555%
# Model's predicted likelihood that the image is a toaster: 0.042520228%
# Model's predicted likelihood that the image is a toaster: 0.042772375%
# Model's predicted likelihood that the image is a toaster: 0.043025357%
# Model's predicted likelihood that the image is a toaster: 0.043285044%
# Model's predicted likelihood that the image is a toaster: 0.043545087%
# Model's predicted likelihood that the image is a toaster: 0.043807735%
# Model's predicted likelihood that the image is a toaster: 0.044075993%
# Model's predicted likelihood that the image is a toaster: 0.044345416%
# Model's predicted likelihood that the image is a toaster: 0.044616582%
# Model's predicted likelihood that the image is a toaster: 0.044889384%
# Model's predicted likelihood that the image is a toaster: 0.045172474%
# Model's predicted likelihood that the image is a toaster: 0.045456967%
# Model's predicted likelihood that the image is a toaster: 0.045744021%
# Model's predicted likelihood that the image is a toaster: 0.046032455%
# Model's predicted likelihood that the image is a toaster: 0.046324456%
# Model's predicted likelihood that the image is a toaster: 0.04661986%
# Model's predicted likelihood that the image is a toaster: 0.046917808%
# Model's predicted likelihood that the image is a toaster: 0.047221076%
# Model's predicted likelihood that the image is a toaster: 0.047528578%
# Model's predicted likelihood that the image is a toaster: 0.04783597%
# Model's predicted likelihood that the image is a toaster: 0.048148626%
# Model's predicted likelihood that the image is a toaster: 0.048466021%
# Model's predicted likelihood that the image is a toaster: 0.048792188%
# Model's predicted likelihood that the image is a toaster: 0.049122469%
# Model's predicted likelihood that the image is a toaster: 0.049452076%
# Model's predicted likelihood that the image is a toaster: 0.049789459%
# Model's predicted likelihood that the image is a toaster: 0.05012225%
# Model's predicted likelihood that the image is a toaster: 0.050453731%
# Model's predicted likelihood that the image is a toaster: 0.050783798%
# Model's predicted likelihood that the image is a toaster: 0.051112281%
# Model's predicted likelihood that the image is a toaster: 0.051444425%
# Model's predicted likelihood that the image is a toaster: 0.051781011%
# Model's predicted likelihood that the image is a toaster: 0.052122516%
# Model's predicted likelihood that the image is a toaster: 0.052467664%
# Model's predicted likelihood that the image is a toaster: 0.052822777%
# Model's predicted likelihood that the image is a toaster: 0.053186988%
# Model's predicted likelihood that the image is a toaster: 0.05355319%
# Model's predicted likelihood that the image is a toaster: 0.053924136%
# Model's predicted likelihood that the image is a toaster: 0.054294907%
# Model's predicted likelihood that the image is a toaster: 0.05466459%
# Model's predicted likelihood that the image is a toaster: 0.055026554%
# Model's predicted likelihood that the image is a toaster: 0.055390975%
# Model's predicted likelihood that the image is a toaster: 0.055757962%
# Model's predicted likelihood that the image is a toaster: 0.0561258%
# Model's predicted likelihood that the image is a toaster: 0.056497147%
# Model's predicted likelihood that the image is a toaster: 0.056871481%
# Model's predicted likelihood that the image is a toaster: 0.057256786%
# Model's predicted likelihood that the image is a toaster: 0.057648245%
# Model's predicted likelihood that the image is a toaster: 0.058042258%
# Model's predicted likelihood that the image is a toaster: 0.05844417%
# Model's predicted likelihood that the image is a toaster: 0.05885642%
# Model's predicted likelihood that the image is a toaster: 0.059280259%
# Model's predicted likelihood that the image is a toaster: 0.059709104%
# Model's predicted likelihood that the image is a toaster: 0.060142804%
# Model's predicted likelihood that the image is a toaster: 0.060584611%
# Model's predicted likelihood that the image is a toaster: 0.061033585%
# Model's predicted likelihood that the image is a toaster: 0.061489729%
# Model's predicted likelihood that the image is a toaster: 0.061957323%
# Model's predicted likelihood that the image is a toaster: 0.062430569%
# Model's predicted likelihood that the image is a toaster: 0.062908314%
# Model's predicted likelihood that the image is a toaster: 0.063394645%
# Model's predicted likelihood that the image is a toaster: 0.063895999%
# Model's predicted likelihood that the image is a toaster: 0.064394024%
# Model's predicted likelihood that the image is a toaster: 0.064893428%
# Model's predicted likelihood that the image is a toaster: 0.065401167%
# Model's predicted likelihood that the image is a toaster: 0.065908622%
# Model's predicted likelihood that the image is a toaster: 0.066424237%
# Model's predicted likelihood that the image is a toaster: 0.066952105%
# Model's predicted likelihood that the image is a toaster: 0.067486695%
# Model's predicted likelihood that the image is a toaster: 0.068025681%
# Model's predicted likelihood that the image is a toaster: 0.068571587%
# Model's predicted likelihood that the image is a toaster: 0.069135072%
# Model's predicted likelihood that the image is a toaster: 0.069715822%
# Model's predicted likelihood that the image is a toaster: 0.070311903%
# Model's predicted likelihood that the image is a toaster: 0.070910197%
# Model's predicted likelihood that the image is a toaster: 0.071520568%
# Model's predicted likelihood that the image is a toaster: 0.072149216%
# Model's predicted likelihood that the image is a toaster: 0.072787568%
# Model's predicted likelihood that the image is a toaster: 0.073432585%
# Model's predicted likelihood that the image is a toaster: 0.074075739%
# Model's predicted likelihood that the image is a toaster: 0.074713136%
# Model's predicted likelihood that the image is a toaster: 0.075356994%
# Model's predicted likelihood that the image is a toaster: 0.076003291%
# Model's predicted likelihood that the image is a toaster: 0.076658494%
# Model's predicted likelihood that the image is a toaster: 0.077330152%
# Model's predicted likelihood that the image is a toaster: 0.078023568%
# Model's predicted likelihood that the image is a toaster: 0.078744133%
# Model's predicted likelihood that the image is a toaster: 0.079492258%
# Model's predicted likelihood that the image is a toaster: 0.080255128%
# Model's predicted likelihood that the image is a toaster: 0.081026828%
# Model's predicted likelihood that the image is a toaster: 0.081842084%
# Model's predicted likelihood that the image is a toaster: 0.082719076%
# Model's predicted likelihood that the image is a toaster: 0.083606649%
# Model's predicted likelihood that the image is a toaster: 0.084502535%
# Model's predicted likelihood that the image is a toaster: 0.085397024%
# Model's predicted likelihood that the image is a toaster: 0.086299574%
# Model's predicted likelihood that the image is a toaster: 0.087224727%
# Model's predicted likelihood that the image is a toaster: 0.088178634%
# Model's predicted likelihood that the image is a toaster: 0.089184922%
# Model's predicted likelihood that the image is a toaster: 0.090225576%
# Model's predicted likelihood that the image is a toaster: 0.091317156%
# Model's predicted likelihood that the image is a toaster: 0.092440436%
# Model's predicted likelihood that the image is a toaster: 0.093630701%
# Model's predicted likelihood that the image is a toaster: 0.094818708%
# Model's predicted likelihood that the image is a toaster: 0.09602856%
# Model's predicted likelihood that the image is a toaster: 0.097297179%
# Model's predicted likelihood that the image is a toaster: 0.098586758%
# Model's predicted likelihood that the image is a toaster: 0.09990636%
# Model's predicted likelihood that the image is a toaster: 0.10122684%
# Model's predicted likelihood that the image is a toaster: 0.10256318%
# Model's predicted likelihood that the image is a toaster: 0.10391994%
# Model's predicted likelihood that the image is a toaster: 0.10532436%
# Model's predicted likelihood that the image is a toaster: 0.10672064%
# Model's predicted likelihood that the image is a toaster: 0.10817485%
# Model's predicted likelihood that the image is a toaster: 0.10971602%
# Model's predicted likelihood that the image is a toaster: 0.11127469%
# Model's predicted likelihood that the image is a toaster: 0.11290845%
# Model's predicted likelihood that the image is a toaster: 0.11453903%
# Model's predicted likelihood that the image is a toaster: 0.11622373%
# Model's predicted likelihood that the image is a toaster: 0.1179788%
# Model's predicted likelihood that the image is a toaster: 0.11980108%
# Model's predicted likelihood that the image is a toaster: 0.12168906%
# Model's predicted likelihood that the image is a toaster: 0.1236545%
# Model's predicted likelihood that the image is a toaster: 0.12565425%
# Model's predicted likelihood that the image is a toaster: 0.12772476%
# Model's predicted likelihood that the image is a toaster: 0.13005795%
# Model's predicted likelihood that the image is a toaster: 0.1325545%
# Model's predicted likelihood that the image is a toaster: 0.13501385%
# Model's predicted likelihood that the image is a toaster: 0.13742228%
# Model's predicted likelihood that the image is a toaster: 0.13974875%
# Model's predicted likelihood that the image is a toaster: 0.14217084%
# Model's predicted likelihood that the image is a toaster: 0.14471862%
# Model's predicted likelihood that the image is a toaster: 0.14728656%
# Model's predicted likelihood that the image is a toaster: 0.14997228%
# Model's predicted likelihood that the image is a toaster: 0.1528003%
# Model's predicted likelihood that the image is a toaster: 0.15579999%
# Model's predicted likelihood that the image is a toaster: 0.15902478%
# Model's predicted likelihood that the image is a toaster: 0.1624311%
# Model's predicted likelihood that the image is a toaster: 0.16605589%
# Model's predicted likelihood that the image is a toaster: 0.1698308%
# Model's predicted likelihood that the image is a toaster: 0.17365697%
# Model's predicted likelihood that the image is a toaster: 0.1776899%
# Model's predicted likelihood that the image is a toaster: 0.18176115%
# Model's predicted likelihood that the image is a toaster: 0.18578348%
# Model's predicted likelihood that the image is a toaster: 0.19000345%
# Model's predicted likelihood that the image is a toaster: 0.19444342%
# Model's predicted likelihood that the image is a toaster: 0.19900808%
# Model's predicted likelihood that the image is a toaster: 0.20381201%
# Model's predicted likelihood that the image is a toaster: 0.20891326%
# Model's predicted likelihood that the image is a toaster: 0.21448596%
# Model's predicted likelihood that the image is a toaster: 0.22056543%
# Model's predicted likelihood that the image is a toaster: 0.22699134%
# Model's predicted likelihood that the image is a toaster: 0.23386814%
# Model's predicted likelihood that the image is a toaster: 0.2409911%
# Model's predicted likelihood that the image is a toaster: 0.2487672%
# Model's predicted likelihood that the image is a toaster: 0.25736506%
# Model's predicted likelihood that the image is a toaster: 0.26727195%
# Model's predicted likelihood that the image is a toaster: 0.27746221%
# Model's predicted likelihood that the image is a toaster: 0.28825905%
# Model's predicted likelihood that the image is a toaster: 0.29976619%
# Model's predicted likelihood that the image is a toaster: 0.3127119%
# Model's predicted likelihood that the image is a toaster: 0.32659536%
# Model's predicted likelihood that the image is a toaster: 0.34127273%
# Model's predicted likelihood that the image is a toaster: 0.35667412%
# Model's predicted likelihood that the image is a toaster: 0.37252372%
# Model's predicted likelihood that the image is a toaster: 0.38952972%
# Model's predicted likelihood that the image is a toaster: 0.40806592%
# Model's predicted likelihood that the image is a toaster: 0.42882264%
# Model's predicted likelihood that the image is a toaster: 0.45397505%
# Model's predicted likelihood that the image is a toaster: 0.48266836%
# Model's predicted likelihood that the image is a toaster: 0.51413123%
# Model's predicted likelihood that the image is a toaster: 0.54984675%
# Model's predicted likelihood that the image is a toaster: 0.59139184%
# Model's predicted likelihood that the image is a toaster: 0.64276289%
# Model's predicted likelihood that the image is a toaster: 0.70505757%
# Model's predicted likelihood that the image is a toaster: 0.78189345%
# Model's predicted likelihood that the image is a toaster: 0.86918594%
# Model's predicted likelihood that the image is a toaster: 0.96720438%
# Model's predicted likelihood that the image is a toaster: 1.0701105%
# Model's predicted likelihood that the image is a toaster: 1.1953643%
# Model's predicted likelihood that the image is a toaster: 1.4725464%
# Model's predicted likelihood that the image is a toaster: 1.8043676%
# Model's predicted likelihood that the image is a toaster: 2.4406459%
# Model's predicted likelihood that the image is a toaster: 3.1049466%
# Model's predicted likelihood that the image is a toaster: 1.8263314%
# Model's predicted likelihood that the image is a toaster: 7.2066255%
# Model's predicted likelihood that the image is a toaster: 2.9791089%
# Model's predicted likelihood that the image is a toaster: 16.746455%
# Model's predicted likelihood that the image is a toaster: 0.24700444%
# Model's predicted likelihood that the image is a toaster: 0.25884626%
# Model's predicted likelihood that the image is a toaster: 0.27156426%
# Model's predicted likelihood that the image is a toaster: 0.28508587%
# Model's predicted likelihood that the image is a toaster: 0.30089458%
# Model's predicted likelihood that the image is a toaster: 0.31913724%
# Model's predicted likelihood that the image is a toaster: 0.33908756%
# Model's predicted likelihood that the image is a toaster: 0.36180932%
# Model's predicted likelihood that the image is a toaster: 0.38811893%
# Model's predicted likelihood that the image is a toaster: 0.41711652%
# Model's predicted likelihood that the image is a toaster: 0.45363726%
# Model's predicted likelihood that the image is a toaster: 0.5031846%
# Model's predicted likelihood that the image is a toaster: 0.57398467%
# Model's predicted likelihood that the image is a toaster: 0.67437394%
# Model's predicted likelihood that the image is a toaster: 0.81047453%
# Model's predicted likelihood that the image is a toaster: 1.0207798%
# Model's predicted likelihood that the image is a toaster: 1.404254%
# Model's predicted likelihood that the image is a toaster: 2.2265725%
# Model's predicted likelihood that the image is a toaster: 4.339188%
# Model's predicted likelihood that the image is a toaster: 12.293966%
# Model's predicted likelihood that the image is a toaster: 25.199649%
# Model's predicted likelihood that the image is a toaster: 16.746506%
# Model's predicted likelihood that the image is a toaster: 8.0075622%
# Model's predicted likelihood that the image is a toaster: 73.27264%
# Model's predicted likelihood that the image is a toaster: 45.843872%
# Model's predicted likelihood that the image is a toaster: 15.418534%
# Model's predicted likelihood that the image is a toaster: 72.611678%
# Model's predicted likelihood that the image is a toaster: 86.853623%

# %%
import numpy as np
from keras.preprocessing import image
from keras.applications import inception_v3

# Load pre-trained image recognition model
model = inception_v3.InceptionV3()

# Load the image file and convert it to a numpy array
img = image.load_img("cat.png", target_size=(299, 299))
input_image = image.img_to_array(img)

# Scale the image so all pixel intensities are between [-1, 1] as the model expects
input_image /= 255.
input_image -= 0.5
input_image *= 2.

# Add a 4th dimension for batch size (as Keras expects)
input_image = np.expand_dims(input_image, axis=0)

# Run the image through the neural network
predictions = model.predict(input_image)

# Convert the predictions into text and print them
predicted_classes = inception_v3.decode_predictions(predictions, top=1)
imagenet_id, name, confidence = predicted_classes[0][0]
print("This is a {} with {:.4}% confidence!".format(name, confidence * 100))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# This is a Persian_cat with 84.74% confidence!

# %%
import numpy as np
from keras.preprocessing import image
from keras.applications import inception_v3

# Load pre-trained image recognition model
model = inception_v3.InceptionV3()

# Load the image file and convert it to a numpy array
img = image.load_img("hacked-image.png", target_size=(299, 299))
input_image = image.img_to_array(img)

# Scale the image so all pixel intensities are between [-1, 1] as the model expects
input_image /= 255.
input_image -= 0.5
input_image *= 2.

# Add a 4th dimension for batch size (as Keras expects)
input_image = np.expand_dims(input_image, axis=0)

# Run the image through the neural network
predictions = model.predict(input_image)

# Convert the predictions into text and print them
predicted_classes = inception_v3.decode_predictions(predictions, top=1)
imagenet_id, name, confidence = predicted_classes[0][0]
print("This is a {} with {:.4}% confidence!".format(name, confidence * 100))
# Out:
# This is a toaster with 98.4% confidence!
